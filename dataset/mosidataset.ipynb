# %%
import h5py

def explore_h5py_structure(item, indent=0):
    """Recursively explore the HDF5 structure."""
    indentation = "  " * indent
    if isinstance(item, h5py.Group):
        print(f"{indentation}Group: {item.name}")
        for key in item.keys():
            explore_h5py_structure(item[key], indent + 1)
    elif isinstance(item, h5py.Dataset):
        print(f"{indentation}Dataset: {item.name}")
        print(f"{indentation}  shape: {item.shape}")
        print(f"{indentation}  dtype: {item.dtype}")
        print(f"{indentation}  values: {item[:5]}...")  # Show the first 5 entries for brevity

def read_cmu_mosei_labels(file_path):
    with h5py.File(file_path, 'r') as f:
        print(type(f))  # Print the type of the file object
        for key in f.keys():
            print(f"Key: {key}")
            explore_h5py_structure(f[key])

if __name__ == '__main__':
    file_path = "/Users/dinesh/College/final proj/attempt3/CMU_MOSI_Opinion_Labels.csd"
    read_cmu_mosei_labels(file_path)
# Out:
# <class 'h5py._hl.files.File'>
# Key: Opinion Segment Labels
# Group: /Opinion Segment Labels
#   Group: /Opinion Segment Labels/data
#     Group: /Opinion Segment Labels/data/03bSnISJMiM
#       Dataset: /Opinion Segment Labels/data/03bSnISJMiM/features
#         shape: (13, 1)
#         dtype: float32
#         values: [[ 2.4 ]
#  [-0.8 ]
#  [-1.  ]
#  [-1.75]
#  [ 0.  ]]...
#       Dataset: /Opinion Segment Labels/data/03bSnISJMiM/intervals
#         shape: (13, 2)
#         dtype: float32
#         values: [[51.904533 55.94535 ]
#  [56.045124 66.78072 ]
#  [66.78072  68.73628 ]
#  [68.73628  70.542175]
#  [70.542175 71.69955 ]]...
#     Group: /Opinion Segment Labels/data/0h-zjBukYpk
#       Dataset: /Opinion Segment Labels/data/0h-zjBukYpk/features
#         shape: (25, 1)
#         dtype: float32
#         values: [[-0.4]
#  [-2.8]
#  [-0.2]
#  [-1.4]
#  [ 0.8]]...
#       Dataset: /Opinion Segment Labels/data/0h-zjBukYpk/intervals
#         shape: (25, 2)
#         dtype: float32
#         values: [[33.705894 37.666893]
#  [43.733105 56.713604]
#  [56.713604 59.766666]
#  [59.766666 63.74762 ]
#  [63.74762  74.89229 ]]...
#     Group: /Opinion Segment Labels/data/1DmNV9C1hbY
#       Dataset: /Opinion Segment Labels/data/1DmNV9C1hbY/features
#         shape: (14, 1)
#         dtype: float32
#         values: [[-2. ]
#  [ 1.6]
#  [ 1. ]
#  [ 2. ]
#  [-1.8]]...
#       Dataset: /Opinion Segment Labels/data/1DmNV9C1hbY/intervals
#         shape: (14, 2)
#         dtype: float32
#         values: [[12.543991 16.405216]
#  [16.405216 20.785261]
#  [20.785261 23.529024]
#  [23.529024 30.134014]
#  [30.134014 33.73583 ]]...
#     Group: /Opinion Segment Labels/data/1iG0909rllw
#       Dataset: /Opinion Segment Labels/data/1iG0909rllw/features
#         shape: (30, 1)
#         dtype: float32
#         values: [[-0.4 ]
#  [-1.75]
#  [ 2.  ]
#  [-1.2 ]
#  [ 2.2 ]]...
#       Dataset: /Opinion Segment Labels/data/1iG0909rllw/intervals
#         shape: (30, 2)
#         dtype: float32
#         values: [[ 6.976644  8.503175]
#  [ 8.503175 10.378912]
#  [10.378912 13.970748]
#  [13.970748 17.5127  ]
#  [17.5127   20.146711]]...
#     Group: /Opinion Segment Labels/data/2WGyTLYerpo
#       Dataset: /Opinion Segment Labels/data/2WGyTLYerpo/features
#         shape: (63, 1)
#         dtype: float32
#         values: [[ 2. ]
#  [ 0.4]
#  [ 0. ]
#  [-0.4]
#  [ 0. ]]...
#       Dataset: /Opinion Segment Labels/data/2WGyTLYerpo/intervals
#         shape: (63, 2)
#         dtype: float32
#         values: [[1.24716554e-02 2.13764167e+00]
#  [2.13764167e+00 2.80612254e+00]
#  [2.80612254e+00 7.57528353e+00]
#  [7.57528353e+00 1.42800455e+01]
#  [1.42800455e+01 1.80913830e+01]]...
#     Group: /Opinion Segment Labels/data/2iD-tVS8NPw
#       Dataset: /Opinion Segment Labels/data/2iD-tVS8NPw/features
#         shape: (30, 1)
#         dtype: float32
#         values: [[-0.5]
#  [ 2.2]
#  [ 1.4]
#  [ 2.2]
#  [ 2. ]]...
#       Dataset: /Opinion Segment Labels/data/2iD-tVS8NPw/intervals
#         shape: (30, 2)
#         dtype: float32
#         values: [[ 5.2605443 11.50635  ]
#  [21.024717  24.536736 ]
#  [24.536736  26.911339 ]
#  [26.911339  32.289116 ]
#  [32.289116  34.085033 ]]...
#     Group: /Opinion Segment Labels/data/5W7Z1C_fDaE
#       Dataset: /Opinion Segment Labels/data/5W7Z1C_fDaE/features
#         shape: (24, 1)
#         dtype: float32
#         values: [[2. ]
#  [1.4]
#  [0.8]
#  [0.4]
#  [2. ]]...
#       Dataset: /Opinion Segment Labels/data/5W7Z1C_fDaE/intervals
#         shape: (24, 2)
#         dtype: float32
#         values: [[ 5.5997734  9.850113 ]
#  [ 9.281405  13.671429 ]
#  [13.671429  14.409751 ]
#  [14.409751  15.257823 ]
#  [15.257823  17.223356 ]]...
#     Group: /Opinion Segment Labels/data/6Egk_28TtTM
#       Dataset: /Opinion Segment Labels/data/6Egk_28TtTM/features
#         shape: (12, 1)
#         dtype: float32
#         values: [[3. ]
#  [2. ]
#  [1.8]
#  [2.8]
#  [2.2]]...
#       Dataset: /Opinion Segment Labels/data/6Egk_28TtTM/intervals
#         shape: (12, 2)
#         dtype: float32
#         values: [[ 4.472336   8.9920635]
#  [31.75034   40.280952 ]
#  [40.280952  51.036507 ]
#  [50.54762   53.04195  ]
#  [53.04195   61.323128 ]]...
#     Group: /Opinion Segment Labels/data/6_0THN4chvY
#       Dataset: /Opinion Segment Labels/data/6_0THN4chvY/features
#         shape: (14, 1)
#         dtype: float32
#         values: [[1.6]
#  [0.6]
#  [2. ]
#  [2. ]
#  [0. ]]...
#       Dataset: /Opinion Segment Labels/data/6_0THN4chvY/intervals
#         shape: (14, 2)
#         dtype: float32
#         values: [[38.485035 44.780727]
#  [50.407936 59.71678 ]
#  [59.71678  63.987076]
#  [63.987076 65.67324 ]
#  [65.67324  66.77075 ]]...
#     Group: /Opinion Segment Labels/data/73jzhE8R1TQ
#       Dataset: /Opinion Segment Labels/data/73jzhE8R1TQ/features
#         shape: (19, 1)
#         dtype: float32
#         values: [[ 1. ]
#  [-0.8]
#  [-0.8]
#  [ 1.6]
#  [-0.8]]...
#       Dataset: /Opinion Segment Labels/data/73jzhE8R1TQ/intervals
#         shape: (19, 2)
#         dtype: float32
#         values: [[73.28594  80.220184]
#  [80.220184 85.328575]
#  [85.328575 90.51678 ]
#  [90.51678  91.32494 ]
#  [91.32494  94.43787 ]]...
#     Group: /Opinion Segment Labels/data/7JsX8y1ysxY
#       Dataset: /Opinion Segment Labels/data/7JsX8y1ysxY/features
#         shape: (39, 1)
#         dtype: float32
#         values: [[ 1.8]
#  [ 2.2]
#  [-2.6]
#  [ 1.4]
#  [ 1. ]]...
#       Dataset: /Opinion Segment Labels/data/7JsX8y1ysxY/intervals
#         shape: (39, 2)
#         dtype: float32
#         values: [[ 9.999773 12.104989]
#  [12.104989 14.739002]
#  [14.739002 16.12585 ]
#  [31.411112 32.478683]
#  [32.478683 46.875965]]...
#     Group: /Opinion Segment Labels/data/8OtFthrtaJM
#       Dataset: /Opinion Segment Labels/data/8OtFthrtaJM/features
#         shape: (23, 1)
#         dtype: float32
#         values: [[ 0.4]
#  [-1. ]
#  [-2.4]
#  [-2. ]
#  [-0.2]]...
#       Dataset: /Opinion Segment Labels/data/8OtFthrtaJM/intervals
#         shape: (23, 2)
#         dtype: float32
#         values: [[16.524942 19.019274]
#  [51.615192 56.075058]
#  [56.075058 64.795235]
#  [64.795235 67.11996 ]
#  [67.11996  70.502266]]...
#     Group: /Opinion Segment Labels/data/8d-gEyoeBzc
#       Dataset: /Opinion Segment Labels/data/8d-gEyoeBzc/features
#         shape: (30, 1)
#         dtype: float32
#         values: [[ 1.2]
#  [-0.8]
#  [-0.2]
#  [-0.2]
#  [-2. ]]...
#       Dataset: /Opinion Segment Labels/data/8d-gEyoeBzc/intervals
#         shape: (30, 2)
#         dtype: float32
#         values: [[ 1.1798186  4.2229023]
#  [ 4.2229023 12.364399 ]
#  [12.364399  26.5322   ]
#  [26.5322    29.62517  ]
#  [29.62517   35.681404 ]]...
#     Group: /Opinion Segment Labels/data/8qrpnFRGt2A
#       Dataset: /Opinion Segment Labels/data/8qrpnFRGt2A/features
#         shape: (26, 1)
#         dtype: float32
#         values: [[-1.4]
#  [-0.4]
#  [-1.6]
#  [-1.4]
#  [-1.4]]...
#       Dataset: /Opinion Segment Labels/data/8qrpnFRGt2A/intervals
#         shape: (26, 2)
#         dtype: float32
#         values: [[ 0.9702948 14.369842 ]
#  [17.343084  20.33628  ]
#  [20.33628   25.763945 ]
#  [25.763945  34.69365  ]
#  [34.69365   40.709976 ]]...
#     Group: /Opinion Segment Labels/data/9J25DZhivz8
#       Dataset: /Opinion Segment Labels/data/9J25DZhivz8/features
#         shape: (25, 1)
#         dtype: float32
#         values: [[2.2]
#  [2.4]
#  [2. ]
#  [2.8]
#  [1.8]]...
#       Dataset: /Opinion Segment Labels/data/9J25DZhivz8/intervals
#         shape: (25, 2)
#         dtype: float32
#         values: [[10.2192745 13.242404 ]
#  [66.8805    69.63424  ]
#  [69.63424   72.67732  ]
#  [72.67732   74.68277  ]
#  [74.68277   76.61837  ]]...
#     Group: /Opinion Segment Labels/data/9T9Hf74oK10
#       Dataset: /Opinion Segment Labels/data/9T9Hf74oK10/features
#         shape: (25, 1)
#         dtype: float32
#         values: [[-0.5]
#  [ 1.6]
#  [-0.4]
#  [-0.8]
#  [-1.8]]...
#       Dataset: /Opinion Segment Labels/data/9T9Hf74oK10/intervals
#         shape: (25, 2)
#         dtype: float32
#         values: [[ 1.1199547  2.1675737]
#  [12.254648  20.366213 ]
#  [28.477777  31.34127  ]
#  [31.34127   33.8356   ]
#  [33.8356    36.828796 ]]...
#     Group: /Opinion Segment Labels/data/9c67fiY0wGQ
#       Dataset: /Opinion Segment Labels/data/9c67fiY0wGQ/features
#         shape: (12, 1)
#         dtype: float32
#         values: [[-0.2]
#  [ 1.8]
#  [ 2. ]
#  [ 2. ]
#  [ 2. ]]...
#       Dataset: /Opinion Segment Labels/data/9c67fiY0wGQ/intervals
#         shape: (12, 2)
#         dtype: float32
#         values: [[ 8.842403 12.573923]
#  [12.573923 15.796598]
#  [38.68458  45.139908]
#  [45.139908 50.577553]
#  [50.577553 54.09955 ]]...
#     Group: /Opinion Segment Labels/data/9qR7uwkblbs
#       Dataset: /Opinion Segment Labels/data/9qR7uwkblbs/features
#         shape: (33, 1)
#         dtype: float32
#         values: [[-0.8]
#  [ 2.8]
#  [ 0.8]
#  [ 3. ]
#  [ 0.8]]...
#       Dataset: /Opinion Segment Labels/data/9qR7uwkblbs/intervals
#         shape: (33, 2)
#         dtype: float32
#         values: [[ 3.314966  6.826984]
#  [11.805669 14.15034 ]
#  [14.15034  16.265533]
#  [50.38798  53.251472]
#  [53.251472 60.485035]]...
#     Group: /Opinion Segment Labels/data/Af8D0E4ZXaw
#       Dataset: /Opinion Segment Labels/data/Af8D0E4ZXaw/features
#         shape: (31, 1)
#         dtype: float32
#         values: [[-0.75]
#  [ 0.8 ]
#  [ 0.25]
#  [-0.4 ]
#  [-0.2 ]]...
#       Dataset: /Opinion Segment Labels/data/Af8D0E4ZXaw/intervals
#         shape: (31, 2)
#         dtype: float32
#         values: [[15.197959 21.962585]
#  [56.673695 64.87505 ]
#  [64.87505  68.97574 ]
#  [68.97574  75.24149 ]
#  [75.24149  80.41973 ]]...
#     Group: /Opinion Segment Labels/data/BI97DNYfe5I
#       Dataset: /Opinion Segment Labels/data/BI97DNYfe5I/features
#         shape: (31, 1)
#         dtype: float32
#         values: [[ 2. ]
#  [-1. ]
#  [-0.2]
#  [ 1.4]
#  [ 1.4]]...
#       Dataset: /Opinion Segment Labels/data/BI97DNYfe5I/intervals
#         shape: (31, 2)
#         dtype: float32
#         values: [[ 8.393424 10.807937]
#  [10.807937 17.62245 ]
#  [17.47279  21.49365 ]
#  [21.49365  24.706348]
#  [24.706348 27.629705]]...
#     Group: /Opinion Segment Labels/data/BXuRRbG0Ugk
#       Dataset: /Opinion Segment Labels/data/BXuRRbG0Ugk/features
#         shape: (31, 1)
#         dtype: float32
#         values: [[-1. ]
#  [ 0.8]
#  [-0.4]
#  [ 0. ]
#  [ 0. ]]...
#       Dataset: /Opinion Segment Labels/data/BXuRRbG0Ugk/intervals
#         shape: (31, 2)
#         dtype: float32
#         values: [[1.2471655e-02 1.2474150e+01]
#  [1.2474150e+01 1.4509523e+01]
#  [1.4509523e+01 1.5996145e+01]
#  [1.5996145e+01 1.9208843e+01]
#  [1.9208843e+01 2.2251928e+01]]...
#     Group: /Opinion Segment Labels/data/Bfr499ggo-0
#       Dataset: /Opinion Segment Labels/data/Bfr499ggo-0/features
#         shape: (22, 1)
#         dtype: float32
#         values: [[-1.75]
#  [-1.  ]
#  [ 1.6 ]
#  [-1.2 ]
#  [-1.8 ]]...
#       Dataset: /Opinion Segment Labels/data/Bfr499ggo-0/intervals
#         shape: (22, 2)
#         dtype: float32
#         values: [[ 2.856009  6.697279]
#  [ 6.697279  8.273696]
#  [ 8.273696 16.395239]
#  [16.395239 18.340816]
#  [18.191156 27.939003]]...
#     Group: /Opinion Segment Labels/data/BioHAh1qJAQ
#       Dataset: /Opinion Segment Labels/data/BioHAh1qJAQ/features
#         shape: (30, 1)
#         dtype: float32
#         values: [[1.4 ]
#  [2.2 ]
#  [0.4 ]
#  [0.25]
#  [1.4 ]]...
#       Dataset: /Opinion Segment Labels/data/BioHAh1qJAQ/intervals
#         shape: (30, 2)
#         dtype: float32
#         values: [[1.2471655e-02 2.3671203e+00]
#  [2.3671203e+00 7.0564628e+00]
#  [7.0564628e+00 1.3531746e+01]
#  [1.3531746e+01 1.8600227e+01]
#  [1.8600227e+01 2.2900454e+01]]...
#     Group: /Opinion Segment Labels/data/BvYR0L6f2Ig
#       Dataset: /Opinion Segment Labels/data/BvYR0L6f2Ig/features
#         shape: (26, 1)
#         dtype: float32
#         values: [[ 1.6]
#  [ 2. ]
#  [ 0.4]
#  [-1. ]
#  [-0.2]]...
#       Dataset: /Opinion Segment Labels/data/BvYR0L6f2Ig/intervals
#         shape: (26, 2)
#         dtype: float32
#         values: [[25.095465 28.198412]
#  [28.198412 33.94535 ]
#  [42.166668 46.197506]
#  [46.197506 47.93356 ]
#  [47.93356  51.016552]]...
#     Group: /Opinion Segment Labels/data/Ci-AH39fi3Y
#       Dataset: /Opinion Segment Labels/data/Ci-AH39fi3Y/features
#         shape: (44, 1)
#         dtype: float32
#         values: [[1.8]
#  [2. ]
#  [0. ]
#  [1.8]
#  [1.6]]...
#       Dataset: /Opinion Segment Labels/data/Ci-AH39fi3Y/intervals
#         shape: (44, 2)
#         dtype: float32
#         values: [[ 4.3725624  5.6496596]
#  [35.531746  40.091385 ]
#  [39.752155  41.43832  ]
#  [41.43832   44.152153 ]
#  [44.152153  45.090023 ]]...
#     Group: /Opinion Segment Labels/data/Clx4VXItLTE
#       Dataset: /Opinion Segment Labels/data/Clx4VXItLTE/features
#         shape: (31, 1)
#         dtype: float32
#         values: [[-1. ]
#  [ 0.6]
#  [ 0.4]
#  [-0.8]
#  [-0.6]]...
#       Dataset: /Opinion Segment Labels/data/Clx4VXItLTE/intervals
#         shape: (31, 2)
#         dtype: float32
#         values: [[16.085941 22.481405]
#  [22.481405 26.612019]
#  [26.612019 27.869162]
#  [30.343538 32.668255]
#  [37.217915 39.333107]]...
#     Group: /Opinion Segment Labels/data/Dg_0XKD0Mf4
#       Dataset: /Opinion Segment Labels/data/Dg_0XKD0Mf4/features
#         shape: (18, 1)
#         dtype: float32
#         values: [[-1. ]
#  [ 0.8]
#  [ 1.4]
#  [ 0.2]
#  [ 1. ]]...
#       Dataset: /Opinion Segment Labels/data/Dg_0XKD0Mf4/intervals
#         shape: (18, 2)
#         dtype: float32
#         values: [[1.2471655e-02 1.6886622e+00]
#  [6.6970291e+01 6.9564400e+01]
#  [6.9564400e+01 7.1460091e+01]
#  [7.1460091e+01 7.2507713e+01]
#  [7.2507713e+01 7.5401131e+01]]...
#     Group: /Opinion Segment Labels/data/G-xst2euQUc
#       Dataset: /Opinion Segment Labels/data/G-xst2euQUc/features
#         shape: (21, 1)
#         dtype: float32
#         values: [[ 2. ]
#  [ 0. ]
#  [-1.4]
#  [-2. ]
#  [ 1.8]]...
#       Dataset: /Opinion Segment Labels/data/G-xst2euQUc/intervals
#         shape: (21, 2)
#         dtype: float32
#         values: [[26.9712   28.348072]
#  [28.348072 29.934467]
#  [29.934467 31.451021]
#  [37.138096 46.726303]
#  [46.726303 49.91905 ]]...
#     Group: /Opinion Segment Labels/data/G6GlGvlkxAQ
#       Dataset: /Opinion Segment Labels/data/G6GlGvlkxAQ/features
#         shape: (29, 1)
#         dtype: float32
#         values: [[2.6]
#  [1. ]
#  [1.2]
#  [1. ]
#  [1.6]]...
#       Dataset: /Opinion Segment Labels/data/G6GlGvlkxAQ/intervals
#         shape: (29, 2)
#         dtype: float32
#         values: [[ 5.559864 11.31678 ]
#  [11.31678  13.631519]
#  [13.631519 15.227891]
#  [29.385714 30.952154]
#  [30.952154 33.795692]]...
#     Group: /Opinion Segment Labels/data/GWuJjcEuzt8
#       Dataset: /Opinion Segment Labels/data/GWuJjcEuzt8/features
#         shape: (18, 1)
#         dtype: float32
#         values: [[ 1.5 ]
#  [ 0.75]
#  [ 2.  ]
#  [-0.4 ]
#  [-1.6 ]]...
#       Dataset: /Opinion Segment Labels/data/GWuJjcEuzt8/intervals
#         shape: (18, 2)
#         dtype: float32
#         values: [[16.554874 22.65102 ]
#  [22.261906 27.430159]
#  [27.430159 31.031973]
#  [35.192516 44.601135]
#  [66.631065 68.36712 ]]...
#     Group: /Opinion Segment Labels/data/HEsqda8_d0Q
#       Dataset: /Opinion Segment Labels/data/HEsqda8_d0Q/features
#         shape: (34, 1)
#         dtype: float32
#         values: [[ 2.8]
#  [ 1.8]
#  [ 2.2]
#  [ 0.2]
#  [-1. ]]...
#       Dataset: /Opinion Segment Labels/data/HEsqda8_d0Q/intervals
#         shape: (34, 2)
#         dtype: float32
#         values: [[ 3.095465   4.831519 ]
#  [ 4.831519   6.5675735]
#  [12.075057  14.349887 ]
#  [14.349887  15.5072565]
#  [15.5072565 19.627892 ]]...
#     Group: /Opinion Segment Labels/data/I5y0__X72p0
#       Dataset: /Opinion Segment Labels/data/I5y0__X72p0/features
#         shape: (39, 1)
#         dtype: float32
#         values: [[ 0.6]
#  [-0.8]
#  [-1.6]
#  [ 0.4]
#  [ 1.4]]...
#       Dataset: /Opinion Segment Labels/data/I5y0__X72p0/intervals
#         shape: (39, 2)
#         dtype: float32
#         values: [[ 8.922222 13.282313]
#  [13.282313 18.510431]
#  [19.55805  29.355782]
#  [29.355782 35.88095 ]
#  [47.025623 47.993423]]...
#     Group: /Opinion Segment Labels/data/Iu2PFX3z_1s
#       Dataset: /Opinion Segment Labels/data/Iu2PFX3z_1s/features
#         shape: (16, 1)
#         dtype: float32
#         values: [[2.4]
#  [1.2]
#  [1.4]
#  [0. ]
#  [1.4]]...
#       Dataset: /Opinion Segment Labels/data/Iu2PFX3z_1s/intervals
#         shape: (16, 2)
#         dtype: float32
#         values: [[15.557143 18.95941 ]
#  [22.491383 27.480045]
#  [27.480045 32.877777]
#  [32.877777 37.07823 ]
#  [48.08322  54.109524]]...
#     Group: /Opinion Segment Labels/data/IumbAb8q2dM
#       Dataset: /Opinion Segment Labels/data/IumbAb8q2dM/features
#         shape: (22, 1)
#         dtype: float32
#         values: [[ 0.5]
#  [-0.5]
#  [ 0.6]
#  [ 2.2]
#  [ 2.6]]...
#       Dataset: /Opinion Segment Labels/data/IumbAb8q2dM/intervals
#         shape: (22, 2)
#         dtype: float32
#         values: [[ 5.9789114  8.014286 ]
#  [ 8.014286   9.201588 ]
#  [12.085034  14.978458 ]
#  [17.871881  21.902721 ]
#  [21.902721  23.1      ]]...
#     Group: /Opinion Segment Labels/data/Jkswaaud0hk
#       Dataset: /Opinion Segment Labels/data/Jkswaaud0hk/features
#         shape: (20, 1)
#         dtype: float32
#         values: [[2.4]
#  [2. ]
#  [2.2]
#  [1. ]
#  [1.8]]...
#       Dataset: /Opinion Segment Labels/data/Jkswaaud0hk/intervals
#         shape: (20, 2)
#         dtype: float32
#         values: [[ 4.7716556  9.470975 ]
#  [ 9.830159  10.877778 ]
#  [10.877778  13.132653 ]
#  [13.132653  14.998413 ]
#  [14.998413  17.32313  ]]...
#     Group: /Opinion Segment Labels/data/LSi-o-IrDMs
#       Dataset: /Opinion Segment Labels/data/LSi-o-IrDMs/features
#         shape: (29, 1)
#         dtype: float32
#         values: [[ 1. ]
#  [-2. ]
#  [ 0. ]
#  [-0.6]
#  [ 0. ]]...
#       Dataset: /Opinion Segment Labels/data/LSi-o-IrDMs/intervals
#         shape: (29, 2)
#         dtype: float32
#         values: [[ 8.353515  9.870068]
#  [ 9.870068 14.010657]
#  [14.010657 17.073696]
#  [17.073696 19.288662]
#  [49.360317 52.173923]]...
#     Group: /Opinion Segment Labels/data/MLal-t_vJPM
#       Dataset: /Opinion Segment Labels/data/MLal-t_vJPM/features
#         shape: (18, 1)
#         dtype: float32
#         values: [[-1.2]
#  [ 1.8]
#  [ 1.6]
#  [ 1.8]
#  [ 2.2]]...
#       Dataset: /Opinion Segment Labels/data/MLal-t_vJPM/intervals
#         shape: (18, 2)
#         dtype: float32
#         values: [[27.060997 30.533106]
#  [32.518593 35.22245 ]
#  [35.22245  36.469616]
#  [36.469616 39.69229 ]
#  [39.69229  43.334015]]...
#     Group: /Opinion Segment Labels/data/Njd1F0vZSm4
#       Dataset: /Opinion Segment Labels/data/Njd1F0vZSm4/features
#         shape: (13, 1)
#         dtype: float32
#         values: [[1.2]
#  [2.8]
#  [2.4]
#  [2.2]
#  [0.2]]...
#       Dataset: /Opinion Segment Labels/data/Njd1F0vZSm4/intervals
#         shape: (13, 2)
#         dtype: float32
#         values: [[ 2.4369614  6.2882085]
#  [ 6.2882085 11.516327 ]
#  [11.516327  14.130385 ]
#  [14.130385  17.392971 ]
#  [17.392971  18.44059  ]]...
#     Group: /Opinion Segment Labels/data/Nzq88NnDkEk
#       Dataset: /Opinion Segment Labels/data/Nzq88NnDkEk/features
#         shape: (32, 1)
#         dtype: float32
#         values: [[-0.4]
#  [-2.8]
#  [-0.4]
#  [-0.8]
#  [-0.2]]...
#       Dataset: /Opinion Segment Labels/data/Nzq88NnDkEk/intervals
#         shape: (32, 2)
#         dtype: float32
#         values: [[ 9.830159 17.931746]
#  [17.931746 22.720861]
#  [22.720861 25.634241]
#  [25.634241 28.777098]
#  [28.777098 30.004309]]...
#     Group: /Opinion Segment Labels/data/OQvJTdtJ2H4
#       Dataset: /Opinion Segment Labels/data/OQvJTdtJ2H4/features
#         shape: (16, 1)
#         dtype: float32
#         values: [[-1. ]
#  [-0.8]
#  [-1.6]
#  [-2. ]
#  [-0.8]]...
#       Dataset: /Opinion Segment Labels/data/OQvJTdtJ2H4/intervals
#         shape: (16, 2)
#         dtype: float32
#         values: [[ 7.415646  8.622903]
#  [ 8.622903 10.00975 ]
#  [10.00975  14.489569]
#  [14.489569 21.603401]
#  [21.603401 23.119955]]...
#     Group: /Opinion Segment Labels/data/OtBXNcAL_lE
#       Dataset: /Opinion Segment Labels/data/OtBXNcAL_lE/features
#         shape: (24, 1)
#         dtype: float32
#         values: [[ 0.2]
#  [-2.6]
#  [-1.2]
#  [-2. ]
#  [-2.8]]...
#       Dataset: /Opinion Segment Labels/data/OtBXNcAL_lE/intervals
#         shape: (24, 2)
#         dtype: float32
#         values: [[ 8.443311 13.172563]
#  [13.172563 17.752153]
#  [17.752153 21.513605]
#  [21.513605 25.514513]
#  [25.514513 32.079594]]...
#     Group: /Opinion Segment Labels/data/Oz06ZWiO20M
#       Dataset: /Opinion Segment Labels/data/Oz06ZWiO20M/features
#         shape: (25, 1)
#         dtype: float32
#         values: [[ 1.4]
#  [-2.4]
#  [ 0. ]
#  [ 1.6]
#  [ 0.2]]...
#       Dataset: /Opinion Segment Labels/data/Oz06ZWiO20M/intervals
#         shape: (25, 2)
#         dtype: float32
#         values: [[17.263266 24.796144]
#  [46.576645 49.958958]
#  [49.958958 53.41111 ]
#  [55.935375 59.74671 ]
#  [59.74671  66.740814]]...
#     Group: /Opinion Segment Labels/data/POKffnXeBds
#       Dataset: /Opinion Segment Labels/data/POKffnXeBds/features
#         shape: (13, 1)
#         dtype: float32
#         values: [[ 0.  ]
#  [-0.4 ]
#  [-1.25]
#  [-2.  ]
#  [-2.  ]]...
#       Dataset: /Opinion Segment Labels/data/POKffnXeBds/intervals
#         shape: (13, 2)
#         dtype: float32
#         values: [[14.958504 16.704535]
#  [21.403854 28.817007]
#  [28.817007 33.456463]
#  [33.456463 35.322224]
#  [35.322224 37.44739 ]]...
#     Group: /Opinion Segment Labels/data/PZ-lDQFboO8
#       Dataset: /Opinion Segment Labels/data/PZ-lDQFboO8/features
#         shape: (12, 1)
#         dtype: float32
#         values: [[-1.4]
#  [-1.8]
#  [-1.6]
#  [-1. ]
#  [ 1.4]]...
#       Dataset: /Opinion Segment Labels/data/PZ-lDQFboO8/intervals
#         shape: (12, 2)
#         dtype: float32
#         values: [[ 9.820182 12.314512]
#  [38.624718 41.428345]
#  [41.428345 47.314964]
#  [47.314964 53.470974]
#  [53.470974 61.46281 ]]...
#     Group: /Opinion Segment Labels/data/QN9ZIUWUXsY
#       Dataset: /Opinion Segment Labels/data/QN9ZIUWUXsY/features
#         shape: (18, 1)
#         dtype: float32
#         values: [[ 0.4]
#  [-1.6]
#  [ 1.2]
#  [-2.4]
#  [ 2.6]]...
#       Dataset: /Opinion Segment Labels/data/QN9ZIUWUXsY/intervals
#         shape: (18, 2)
#         dtype: float32
#         values: [[36.250114 46.127663]
#  [50.896824 52.842403]
#  [52.842403 54.468708]
#  [77.526306 81.87642 ]
#  [81.87642  85.30862 ]]...
#     Group: /Opinion Segment Labels/data/Qr1Ca94K55A
#       Dataset: /Opinion Segment Labels/data/Qr1Ca94K55A/features
#         shape: (14, 1)
#         dtype: float32
#         values: [[ 3. ]
#  [-2. ]
#  [-1.6]
#  [ 1.4]
#  [-1.6]]...
#       Dataset: /Opinion Segment Labels/data/Qr1Ca94K55A/intervals
#         shape: (14, 2)
#         dtype: float32
#         values: [[ 8.423356 13.372108]
#  [43.473698 45.090023]
#  [45.090023 46.307255]
#  [46.307255 52.97211 ]
#  [65.75306  68.42699 ]]...
#     Group: /Opinion Segment Labels/data/Sqr0AcuoNnk
#       Dataset: /Opinion Segment Labels/data/Sqr0AcuoNnk/features
#         shape: (22, 1)
#         dtype: float32
#         values: [[-0.75]
#  [-1.8 ]
#  [ 0.6 ]
#  [-2.2 ]
#  [-2.2 ]]...
#       Dataset: /Opinion Segment Labels/data/Sqr0AcuoNnk/intervals
#         shape: (22, 2)
#         dtype: float32
#         values: [[15.038322 18.819727]
#  [18.819727 22.61111 ]
#  [22.61111  25.953514]
#  [25.953514 33.795692]
#  [33.795692 35.85102 ]]...
#     Group: /Opinion Segment Labels/data/TvyZBvOMOTc
#       Dataset: /Opinion Segment Labels/data/TvyZBvOMOTc/features
#         shape: (15, 1)
#         dtype: float32
#         values: [[-0.2]
#  [ 2.2]
#  [ 2. ]
#  [ 1.4]
#  [ 1.2]]...
#       Dataset: /Opinion Segment Labels/data/TvyZBvOMOTc/intervals
#         shape: (15, 2)
#         dtype: float32
#         values: [[ 4.721769   6.7371883]
#  [20.106802  21.104536 ]
#  [21.104536  26.0034   ]
#  [26.0034    30.253742 ]
#  [30.253742  33.127213 ]]...
#     Group: /Opinion Segment Labels/data/VCslbP0mgZI
#       Dataset: /Opinion Segment Labels/data/VCslbP0mgZI/features
#         shape: (17, 1)
#         dtype: float32
#         values: [[-2.5]
#  [-0.6]
#  [ 0. ]
#  [-2.6]
#  [ 0.4]]...
#       Dataset: /Opinion Segment Labels/data/VCslbP0mgZI/intervals
#         shape: (17, 2)
#         dtype: float32
#         values: [[ 1.6886622  1.778458 ]
#  [ 1.778458   7.3557825]
#  [12.88322   17.402948 ]
#  [31.251474  42.08685  ]
#  [42.08685   50.697277 ]]...
#     Group: /Opinion Segment Labels/data/VbQk4H8hgr0
#       Dataset: /Opinion Segment Labels/data/VbQk4H8hgr0/features
#         shape: (55, 1)
#         dtype: float32
#         values: [[-2.2]
#  [ 2. ]
#  [-0.8]
#  [-2.2]
#  [-2.2]]...
#       Dataset: /Opinion Segment Labels/data/VbQk4H8hgr0/intervals
#         shape: (55, 2)
#         dtype: float32
#         values: [[15.8863945 19.14898  ]
#  [19.14898   22.621088 ]
#  [22.321768  24.806122 ]
#  [24.806122  27.819275 ]
#  [27.819275  29.136282 ]]...
#     Group: /Opinion Segment Labels/data/Vj1wYRQjB-o
#       Dataset: /Opinion Segment Labels/data/Vj1wYRQjB-o/features
#         shape: (9, 1)
#         dtype: float32
#         values: [[ 1.4]
#  [ 2.2]
#  [-0.8]
#  [-0.8]
#  [ 0.5]]...
#       Dataset: /Opinion Segment Labels/data/Vj1wYRQjB-o/intervals
#         shape: (9, 2)
#         dtype: float32
#         values: [[122.82336 128.25102]
#  [128.25102 133.13991]
#  [133.13991 135.0855 ]
#  [135.0855  136.28276]
#  [158.41248 159.73946]]...
#     Group: /Opinion Segment Labels/data/W8NXH0Djyww
#       Dataset: /Opinion Segment Labels/data/W8NXH0Djyww/features
#         shape: (32, 1)
#         dtype: float32
#         values: [[ 2.8 ]
#  [-0.25]
#  [ 2.4 ]
#  [ 0.6 ]
#  [-0.8 ]]...
#       Dataset: /Opinion Segment Labels/data/W8NXH0Djyww/intervals
#         shape: (32, 2)
#         dtype: float32
#         values: [[ 5.220635  9.121769]
#  [ 9.121769 10.04966 ]
#  [10.04966  12.02517 ]
#  [25.22517  27.729479]
#  [27.729479 30.63288 ]]...
#     Group: /Opinion Segment Labels/data/WKA5OygbEKI
#       Dataset: /Opinion Segment Labels/data/WKA5OygbEKI/features
#         shape: (22, 1)
#         dtype: float32
#         values: [[1.8]
#  [2.2]
#  [1.2]
#  [1.8]
#  [0.6]]...
#       Dataset: /Opinion Segment Labels/data/WKA5OygbEKI/intervals
#         shape: (22, 2)
#         dtype: float32
#         values: [[ 4.4024944  8.762585 ]
#  [14.70907   16.884127 ]
#  [45.3195    49.659637 ]
#  [49.659637  51.944443 ]
#  [51.944443  58.04059  ]]...
#     Group: /Opinion Segment Labels/data/X3j2zQgwYgE
#       Dataset: /Opinion Segment Labels/data/X3j2zQgwYgE/features
#         shape: (11, 1)
#         dtype: float32
#         values: [[ 0.8]
#  [-1.6]
#  [-2. ]
#  [ 0.2]
#  [-2.2]]...
#       Dataset: /Opinion Segment Labels/data/X3j2zQgwYgE/intervals
#         shape: (11, 2)
#         dtype: float32
#         values: [[ 4.981179   6.5376415]
#  [41.049206  48.52222  ]
#  [48.52222   50.637417 ]
#  [50.637417  51.874603 ]
#  [51.874603  53.690475 ]]...
#     Group: /Opinion Segment Labels/data/ZAIRrfG22O0
#       Dataset: /Opinion Segment Labels/data/ZAIRrfG22O0/features
#         shape: (9, 1)
#         dtype: float32
#         values: [[-2.  ]
#  [-2.6 ]
#  [ 0.6 ]
#  [-2.4 ]
#  [ 1.25]]...
#       Dataset: /Opinion Segment Labels/data/ZAIRrfG22O0/intervals
#         shape: (9, 2)
#         dtype: float32
#         values: [[ 5.5199547  9.530839 ]
#  [ 9.530839  12.134921 ]
#  [12.134921  13.89093  ]
#  [13.89093   17.273243 ]
#  [17.273243  21.453741 ]]...
#     Group: /Opinion Segment Labels/data/ZUXBRvtny7o
#       Dataset: /Opinion Segment Labels/data/ZUXBRvtny7o/features
#         shape: (34, 1)
#         dtype: float32
#         values: [[ 2.25]
#  [-1.4 ]
#  [ 1.  ]
#  [ 1.8 ]
#  [ 1.4 ]]...
#       Dataset: /Opinion Segment Labels/data/ZUXBRvtny7o/intervals
#         shape: (34, 2)
#         dtype: float32
#         values: [[1.2471655e-02 6.8768706e+00]
#  [6.8768706e+00 9.8501129e+00]
#  [9.8501129e+00 1.3282313e+01]
#  [1.3282313e+01 1.4778912e+01]
#  [1.4778912e+01 1.7023809e+01]]...
#     Group: /Opinion Segment Labels/data/_dI--eQ6qVU
#       Dataset: /Opinion Segment Labels/data/_dI--eQ6qVU/features
#         shape: (28, 1)
#         dtype: float32
#         values: [[ 2.4]
#  [ 3. ]
#  [-0.2]
#  [ 3. ]
#  [ 3. ]]...
#       Dataset: /Opinion Segment Labels/data/_dI--eQ6qVU/intervals
#         shape: (28, 2)
#         dtype: float32
#         values: [[27.39025  32.68821 ]
#  [44.99025  46.606575]
#  [46.606575 58.52948 ]
#  [58.52948  67.21973 ]
#  [67.21973  70.472336]]...
#     Group: /Opinion Segment Labels/data/aiEXnCPZubE
#       Dataset: /Opinion Segment Labels/data/aiEXnCPZubE/features
#         shape: (30, 1)
#         dtype: float32
#         values: [[-2.2]
#  [-1.2]
#  [-0.6]
#  [-1.6]
#  [ 0. ]]...
#       Dataset: /Opinion Segment Labels/data/aiEXnCPZubE/intervals
#         shape: (30, 2)
#         dtype: float32
#         values: [[ 90.62653  92.35261]
#  [ 92.35261  94.73719]
#  [ 94.73719  95.80476]
#  [ 95.80476  97.6805 ]
#  [100.02517 101.89093]]...
#     Group: /Opinion Segment Labels/data/atnd_PF-Lbs
#       Dataset: /Opinion Segment Labels/data/atnd_PF-Lbs/features
#         shape: (21, 1)
#         dtype: float32
#         values: [[-3. ]
#  [-3. ]
#  [-1.2]
#  [-2.4]
#  [-2.8]]...
#       Dataset: /Opinion Segment Labels/data/atnd_PF-Lbs/intervals
#         shape: (21, 2)
#         dtype: float32
#         values: [[59.706802 70.2229  ]
#  [70.2229   72.97665 ]
#  [79.621544 84.32086 ]
#  [84.32086  90.99569 ]
#  [90.99569  91.96349 ]]...
#     Group: /Opinion Segment Labels/data/bOL9jKpeJRs
#       Dataset: /Opinion Segment Labels/data/bOL9jKpeJRs/features
#         shape: (34, 1)
#         dtype: float32
#         values: [[3. ]
#  [1.6]
#  [2. ]
#  [2.4]
#  [1.4]]...
#       Dataset: /Opinion Segment Labels/data/bOL9jKpeJRs/intervals
#         shape: (34, 2)
#         dtype: float32
#         values: [[ 7.62517  12.184807]
#  [12.184807 14.200227]
#  [14.200227 15.976191]
#  [15.976191 19.228798]
#  [19.228798 21.763039]]...
#     Group: /Opinion Segment Labels/data/bvLlb-M3UXU
#       Dataset: /Opinion Segment Labels/data/bvLlb-M3UXU/features
#         shape: (25, 1)
#         dtype: float32
#         values: [[-0.2]
#  [-2.2]
#  [-2.4]
#  [ 2.2]
#  [-1.2]]...
#       Dataset: /Opinion Segment Labels/data/bvLlb-M3UXU/intervals
#         shape: (25, 2)
#         dtype: float32
#         values: [[21.892744 25.724037]
#  [25.354876 28.627438]
#  [28.627438 31.770294]
#  [31.770294 36.389797]
#  [46.576645 50.76712 ]]...
#     Group: /Opinion Segment Labels/data/c5xsKMxpXnc
#       Dataset: /Opinion Segment Labels/data/c5xsKMxpXnc/features
#         shape: (15, 1)
#         dtype: float32
#         values: [[-0.75]
#  [-2.6 ]
#  [-1.8 ]
#  [ 2.  ]
#  [-2.2 ]]...
#       Dataset: /Opinion Segment Labels/data/c5xsKMxpXnc/intervals
#         shape: (15, 2)
#         dtype: float32
#         values: [[  1.868254    5.080952 ]
#  [  5.080952    7.3258505]
#  [ 39.72222    42.59569  ]
#  [132.52132   135.63425  ]
#  [142.13945   146.24014  ]]...
#     Group: /Opinion Segment Labels/data/c7UH_rxdZv4
#       Dataset: /Opinion Segment Labels/data/c7UH_rxdZv4/features
#         shape: (33, 1)
#         dtype: float32
#         values: [[-2.8]
#  [-2.6]
#  [-0.8]
#  [ 1.6]
#  [-2.2]]...
#       Dataset: /Opinion Segment Labels/data/c7UH_rxdZv4/intervals
#         shape: (33, 2)
#         dtype: float32
#         values: [[ 4.2029476  8.054195 ]
#  [ 8.054195  10.079592 ]
#  [10.079592  12.144898 ]
#  [11.785714  17.09365  ]
#  [21.543537  26.292744 ]]...
#     Group: /Opinion Segment Labels/data/cM3Yna7AavY
#       Dataset: /Opinion Segment Labels/data/cM3Yna7AavY/features
#         shape: (16, 1)
#         dtype: float32
#         values: [[2.2]
#  [2.5]
#  [1. ]
#  [0.6]
#  [2.8]]...
#       Dataset: /Opinion Segment Labels/data/cM3Yna7AavY/intervals
#         shape: (16, 2)
#         dtype: float32
#         values: [[26.442404 37.91633 ]
#  [37.91633  41.43832 ]
#  [41.43832  45.57891 ]
#  [45.57891  54.12948 ]
#  [54.12948  59.61701 ]]...
#     Group: /Opinion Segment Labels/data/cW1FSBF59ik
#       Dataset: /Opinion Segment Labels/data/cW1FSBF59ik/features
#         shape: (24, 1)
#         dtype: float32
#         values: [[-2.6]
#  [ 3. ]
#  [-1. ]
#  [ 1.6]
#  [ 2. ]]...
#       Dataset: /Opinion Segment Labels/data/cW1FSBF59ik/intervals
#         shape: (24, 2)
#         dtype: float32
#         values: [[ 5.2405896 11.815646 ]
#  [11.815646  24.44694  ]
#  [28.876871  33.01746  ]
#  [48.651928  56.73356  ]
#  [56.73356   58.369843 ]]...
#     Group: /Opinion Segment Labels/data/cXypl4FnoZo
#       Dataset: /Opinion Segment Labels/data/cXypl4FnoZo/features
#         shape: (29, 1)
#         dtype: float32
#         values: [[ 1. ]
#  [ 1. ]
#  [ 1.8]
#  [-0.8]
#  [ 1.8]]...
#       Dataset: /Opinion Segment Labels/data/cXypl4FnoZo/intervals
#         shape: (29, 2)
#         dtype: float32
#         values: [[ 3.3249433  5.6097507]
#  [ 8.193877  11.835601 ]
#  [14.110431  15.636961 ]
#  [15.636961  22.491383 ]
#  [22.491383  25.833786 ]]...
#     Group: /Opinion Segment Labels/data/d3_k5Xpfmik
#       Dataset: /Opinion Segment Labels/data/d3_k5Xpfmik/features
#         shape: (19, 1)
#         dtype: float32
#         values: [[ 2. ]
#  [ 0. ]
#  [ 2. ]
#  [-1. ]
#  [ 2.2]]...
#       Dataset: /Opinion Segment Labels/data/d3_k5Xpfmik/intervals
#         shape: (19, 2)
#         dtype: float32
#         values: [[13.970748 21.304081]
#  [26.631973 29.385714]
#  [44.631065 50.268253]
#  [74.66281  78.74354 ]
#  [78.74354  81.8864  ]]...
#     Group: /Opinion Segment Labels/data/d6hH302o4v8
#       Dataset: /Opinion Segment Labels/data/d6hH302o4v8/features
#         shape: (43, 1)
#         dtype: float32
#         values: [[-2.8      ]
#  [-1.8      ]
#  [ 0.2      ]
#  [-1.6      ]
#  [-1.3333334]]...
#       Dataset: /Opinion Segment Labels/data/d6hH302o4v8/intervals
#         shape: (43, 2)
#         dtype: float32
#         values: [[ 5.5698414  9.351247 ]
#  [ 9.351247  13.751247 ]
#  [13.751247  19.308617 ]
#  [19.308617  21.274149 ]
#  [21.274149  22.361677 ]]...
#     Group: /Opinion Segment Labels/data/dq3Nf_lMPnE
#       Dataset: /Opinion Segment Labels/data/dq3Nf_lMPnE/features
#         shape: (15, 1)
#         dtype: float32
#         values: [[ 0. ]
#  [-1.4]
#  [-1.2]
#  [-0.4]
#  [ 1.2]]...
#       Dataset: /Opinion Segment Labels/data/dq3Nf_lMPnE/intervals
#         shape: (15, 2)
#         dtype: float32
#         values: [[ 0.20204082  4.671882  ]
#  [13.89093    16.085941  ]
#  [16.085941   18.081406  ]
#  [18.081406   28.078686  ]
#  [27.619728   30.792517  ]]...
#     Group: /Opinion Segment Labels/data/etzxEpPuc6I
#       Dataset: /Opinion Segment Labels/data/etzxEpPuc6I/features
#         shape: (19, 1)
#         dtype: float32
#         values: [[ 0.4]
#  [ 1.2]
#  [-1.6]
#  [ 0.8]
#  [ 0. ]]...
#       Dataset: /Opinion Segment Labels/data/etzxEpPuc6I/intervals
#         shape: (19, 2)
#         dtype: float32
#         values: [[34.124943 42.815193]
#  [43.04467  46.88594 ]
#  [64.39615  69.40476 ]
#  [69.165306 74.84241 ]
#  [74.84241  80.36984 ]]...
#     Group: /Opinion Segment Labels/data/f9O3YtZ2VfI
#       Dataset: /Opinion Segment Labels/data/f9O3YtZ2VfI/features
#         shape: (30, 1)
#         dtype: float32
#         values: [[-1.2 ]
#  [ 1.25]
#  [ 0.6 ]
#  [-2.4 ]
#  [-1.8 ]]...
#       Dataset: /Opinion Segment Labels/data/f9O3YtZ2VfI/intervals
#         shape: (30, 2)
#         dtype: float32
#         values: [[15.816553 17.91179 ]
#  [26.821543 28.717234]
#  [28.717234 32.149433]
#  [32.149433 37.138096]
#  [37.138096 44.122223]]...
#     Group: /Opinion Segment Labels/data/f_pcplsH_V0
#       Dataset: /Opinion Segment Labels/data/f_pcplsH_V0/features
#         shape: (15, 1)
#         dtype: float32
#         values: [[0.25]
#  [1.4 ]
#  [0.8 ]
#  [0.5 ]
#  [1.2 ]]...
#       Dataset: /Opinion Segment Labels/data/f_pcplsH_V0/intervals
#         shape: (15, 2)
#         dtype: float32
#         values: [[10.329025 13.232427]
#  [17.592518 21.214285]
#  [29.096373 34.464172]
#  [34.464172 42.146713]
#  [88.23197  99.50635 ]]...
#     Group: /Opinion Segment Labels/data/fvVhgmXxadc
#       Dataset: /Opinion Segment Labels/data/fvVhgmXxadc/features
#         shape: (14, 1)
#         dtype: float32
#         values: [[-0.4]
#  [-2.8]
#  [-2.2]
#  [-2.8]
#  [ 0. ]]...
#       Dataset: /Opinion Segment Labels/data/fvVhgmXxadc/intervals
#         shape: (14, 2)
#         dtype: float32
#         values: [[15.597053 20.446032]
#  [20.446032 27.001133]
#  [27.001133 28.447845]
#  [28.447845 30.513151]
#  [42.555782 46.00794 ]]...
#     Group: /Opinion Segment Labels/data/iiK8YX8oH1E
#       Dataset: /Opinion Segment Labels/data/iiK8YX8oH1E/features
#         shape: (18, 1)
#         dtype: float32
#         values: [[-2.6 ]
#  [ 1.2 ]
#  [-1.25]
#  [-2.  ]
#  [-0.4 ]]...
#       Dataset: /Opinion Segment Labels/data/iiK8YX8oH1E/intervals
#         shape: (18, 2)
#         dtype: float32
#         values: [[ 3.4646258  6.178458 ]
#  [ 6.178458   9.75034  ]
#  [23.76848   25.7839   ]
#  [25.7839    29.305895 ]
#  [29.305895  40.919502 ]]...
#     Group: /Opinion Segment Labels/data/jUzDDGyPkXU
#       Dataset: /Opinion Segment Labels/data/jUzDDGyPkXU/features
#         shape: (27, 1)
#         dtype: float32
#         values: [[ 2.8]
#  [ 2.6]
#  [ 0. ]
#  [-1.6]
#  [-1.2]]...
#       Dataset: /Opinion Segment Labels/data/jUzDDGyPkXU/intervals
#         shape: (27, 2)
#         dtype: float32
#         values: [[28.437868 29.904535]
#  [29.904535 31.969841]
#  [31.969841 34.823357]
#  [34.982994 44.680954]
#  [44.680954 48.64195 ]]...
#     Group: /Opinion Segment Labels/data/k5Y_838nuGo
#       Dataset: /Opinion Segment Labels/data/k5Y_838nuGo/features
#         shape: (31, 1)
#         dtype: float32
#         values: [[-1.6      ]
#  [ 1.2      ]
#  [ 0.8      ]
#  [ 1.       ]
#  [-1.3333334]]...
#       Dataset: /Opinion Segment Labels/data/k5Y_838nuGo/intervals
#         shape: (31, 2)
#         dtype: float32
#         values: [[27.420181 29.505442]
#  [29.505442 31.690475]
#  [77.13719  82.55488 ]
#  [82.55488  84.34081 ]
#  [84.34081  87.04467 ]]...
#     Group: /Opinion Segment Labels/data/lXPQBPVc5Cw
#       Dataset: /Opinion Segment Labels/data/lXPQBPVc5Cw/features
#         shape: (30, 1)
#         dtype: float32
#         values: [[ 0.2]
#  [-2.2]
#  [-2.4]
#  [-1.2]
#  [-1. ]]...
#       Dataset: /Opinion Segment Labels/data/lXPQBPVc5Cw/intervals
#         shape: (30, 2)
#         dtype: float32
#         values: [[14.050567 19.06916 ]
#  [19.06916  22.880499]
#  [22.880499 25.60431 ]
#  [25.60431  33.795692]
#  [33.795692 41.14898 ]]...
#     Group: /Opinion Segment Labels/data/nbWiPyCm4g0
#       Dataset: /Opinion Segment Labels/data/nbWiPyCm4g0/features
#         shape: (10, 1)
#         dtype: float32
#         values: [[ 1.2]
#  [-2.4]
#  [-1.8]
#  [-2.2]
#  [-1.4]]...
#       Dataset: /Opinion Segment Labels/data/nbWiPyCm4g0/intervals
#         shape: (10, 2)
#         dtype: float32
#         values: [[ 1.9879819  4.64195  ]
#  [ 4.64195    7.2061224]
#  [ 7.2061224 10.897733 ]
#  [10.897733  22.621088 ]
#  [22.621088  31.171656 ]]...
#     Group: /Opinion Segment Labels/data/nzpVDcQ0ywM
#       Dataset: /Opinion Segment Labels/data/nzpVDcQ0ywM/features
#         shape: (24, 1)
#         dtype: float32
#         values: [[ 0. ]
#  [-1.6]
#  [ 0.8]
#  [-1.6]
#  [-0.4]]...
#       Dataset: /Opinion Segment Labels/data/nzpVDcQ0ywM/intervals
#         shape: (24, 2)
#         dtype: float32
#         values: [[ 5.410204 10.438775]
#  [10.438775 13.571655]
#  [13.571655 18.7     ]
#  [18.7      25.734015]
#  [25.734015 29.385714]]...
#     Group: /Opinion Segment Labels/data/ob23OKe5a9Q
#       Dataset: /Opinion Segment Labels/data/ob23OKe5a9Q/features
#         shape: (14, 1)
#         dtype: float32
#         values: [[ 1.2]
#  [ 1. ]
#  [-1.2]
#  [-1.5]
#  [-1.8]]...
#       Dataset: /Opinion Segment Labels/data/ob23OKe5a9Q/intervals
#         shape: (14, 2)
#         dtype: float32
#         values: [[12.613832 15.207936]
#  [15.207936 16.734467]
#  [16.734467 20.166666]
#  [23.778458 25.52449 ]
#  [41.867348 53.650566]]...
#     Group: /Opinion Segment Labels/data/pLTX3ipuDJI
#       Dataset: /Opinion Segment Labels/data/pLTX3ipuDJI/features
#         shape: (16, 1)
#         dtype: float32
#         values: [[-2.4]
#  [-1.8]
#  [-1.2]
#  [-2.2]
#  [-2. ]]...
#       Dataset: /Opinion Segment Labels/data/pLTX3ipuDJI/intervals
#         shape: (16, 2)
#         dtype: float32
#         values: [[13.322222 18.44059 ]
#  [18.44059  29.864626]
#  [29.864626 34.743538]
#  [34.743538 43.83288 ]
#  [43.83288  50.118595]]...
#     Group: /Opinion Segment Labels/data/phBUpBr1hSo
#       Dataset: /Opinion Segment Labels/data/phBUpBr1hSo/features
#         shape: (21, 1)
#         dtype: float32
#         values: [[ 1.4]
#  [ 2.2]
#  [ 2.8]
#  [-0.8]
#  [-1.4]]...
#       Dataset: /Opinion Segment Labels/data/phBUpBr1hSo/intervals
#         shape: (21, 2)
#         dtype: float32
#         values: [[ 7.1462584  8.912245 ]
#  [ 8.912245  10.658277 ]
#  [10.658277  14.389796 ]
#  [14.389796  23.499092 ]
#  [34.66372   40.001587 ]]...
#     Group: /Opinion Segment Labels/data/rnaNMUZpvvg
#       Dataset: /Opinion Segment Labels/data/rnaNMUZpvvg/features
#         shape: (22, 1)
#         dtype: float32
#         values: [[-2.6 ]
#  [ 2.25]
#  [-0.8 ]
#  [-2.4 ]
#  [-2.8 ]]...
#       Dataset: /Opinion Segment Labels/data/rnaNMUZpvvg/intervals
#         shape: (22, 2)
#         dtype: float32
#         values: [[1.2471655e-02 4.2428570e+00]
#  [6.6573696e+00 8.5031748e+00]
#  [8.5031748e+00 1.0049660e+01]
#  [1.0049660e+01 2.5354876e+01]
#  [2.5414740e+01 2.8926758e+01]]...
#     Group: /Opinion Segment Labels/data/tIrG4oNLFzE
#       Dataset: /Opinion Segment Labels/data/tIrG4oNLFzE/features
#         shape: (18, 1)
#         dtype: float32
#         values: [[2.8]
#  [2.4]
#  [2.6]
#  [1.4]
#  [0.4]]...
#       Dataset: /Opinion Segment Labels/data/tIrG4oNLFzE/intervals
#         shape: (18, 2)
#         dtype: float32
#         values: [[18.95941  25.424717]
#  [25.424717 28.098639]
#  [28.098639 31.451021]
#  [33.68594  36.918594]
#  [39.21338  42.096825]]...
#     Group: /Opinion Segment Labels/data/tStelxIAHjw
#       Dataset: /Opinion Segment Labels/data/tStelxIAHjw/features
#         shape: (16, 1)
#         dtype: float32
#         values: [[ 0. ]
#  [-2. ]
#  [ 0.5]
#  [-2.8]
#  [-2.2]]...
#       Dataset: /Opinion Segment Labels/data/tStelxIAHjw/intervals
#         shape: (16, 2)
#         dtype: float32
#         values: [[13.162585 19.178911]
#  [19.178911 32.668255]
#  [32.668255 34.553967]
#  [34.553967 44.61111 ]
#  [44.61111  47.434692]]...
#     Group: /Opinion Segment Labels/data/tmZoasNr4rU
#       Dataset: /Opinion Segment Labels/data/tmZoasNr4rU/features
#         shape: (20, 1)
#         dtype: float32
#         values: [[ 0. ]
#  [-2. ]
#  [-2. ]
#  [-0.8]
#  [-0.8]]...
#       Dataset: /Opinion Segment Labels/data/tmZoasNr4rU/intervals
#         shape: (20, 2)
#         dtype: float32
#         values: [[ 2.357143   5.7095237]
#  [ 5.7095237 12.84331  ]
#  [12.84331   15.098186 ]
#  [19.488209  35.082767 ]
#  [35.082767  38.894104 ]]...
#     Group: /Opinion Segment Labels/data/v0zCBqDeKcE
#       Dataset: /Opinion Segment Labels/data/v0zCBqDeKcE/features
#         shape: (16, 1)
#         dtype: float32
#         values: [[ 2.6]
#  [-0.4]
#  [ 0.6]
#  [ 0. ]
#  [ 2. ]]...
#       Dataset: /Opinion Segment Labels/data/v0zCBqDeKcE/intervals
#         shape: (16, 2)
#         dtype: float32
#         values: [[ 2.8759637  5.0909295]
#  [18.131292  22.970295 ]
#  [28.018822  32.528572 ]
#  [32.528572  37.587074 ]
#  [37.587074  40.19116  ]]...
#     Group: /Opinion Segment Labels/data/vvZ4IcEtiZc
#       Dataset: /Opinion Segment Labels/data/vvZ4IcEtiZc/features
#         shape: (12, 1)
#         dtype: float32
#         values: [[2. ]
#  [2.4]
#  [1.4]
#  [2.2]
#  [1.2]]...
#       Dataset: /Opinion Segment Labels/data/vvZ4IcEtiZc/intervals
#         shape: (12, 2)
#         dtype: float32
#         values: [[ 9.361224 11.336735]
#  [11.336735 14.180272]
#  [14.180272 22.810658]
#  [22.810658 32.408844]
#  [37.028343 40.55034 ]]...
#     Group: /Opinion Segment Labels/data/vyB00TXsimI
#       Dataset: /Opinion Segment Labels/data/vyB00TXsimI/features
#         shape: (22, 1)
#         dtype: float32
#         values: [[ 0. ]
#  [-2.4]
#  [ 2.2]
#  [ 1.8]
#  [ 1.8]]...
#       Dataset: /Opinion Segment Labels/data/vyB00TXsimI/intervals
#         shape: (22, 2)
#         dtype: float32
#         values: [[ 5.7095237  7.814739 ]
#  [22.072336  30.124037 ]
#  [30.124037  40.131294 ]
#  [70.96123   73.39569  ]
#  [73.39569   74.7127   ]]...
#     Group: /Opinion Segment Labels/data/wMbj6ajWbic
#       Dataset: /Opinion Segment Labels/data/wMbj6ajWbic/features
#         shape: (30, 1)
#         dtype: float32
#         values: [[ 0.5]
#  [-0.8]
#  [ 0. ]
#  [ 1. ]
#  [ 0.2]]...
#       Dataset: /Opinion Segment Labels/data/wMbj6ajWbic/intervals
#         shape: (30, 2)
#         dtype: float32
#         values: [[11.526304 13.292291]
#  [21.83288  30.343538]
#  [30.343538 32.787983]
#  [36.349888 38.27551 ]
#  [65.55351  71.39025 ]]...
#     Group: /Opinion Segment Labels/data/yDtzw_Y-7RU
#       Dataset: /Opinion Segment Labels/data/yDtzw_Y-7RU/features
#         shape: (24, 1)
#         dtype: float32
#         values: [[ 0.8 ]
#  [ 0.8 ]
#  [ 0.75]
#  [-1.  ]
#  [ 0.5 ]]...
#       Dataset: /Opinion Segment Labels/data/yDtzw_Y-7RU/intervals
#         shape: (24, 2)
#         dtype: float32
#         values: [[ 4.3825397  8.48322  ]
#  [11.127211  22.421541 ]
#  [33.007484  38.145805 ]
#  [38.145805  45.299545 ]
#  [50.76712   56.673695 ]]...
#     Group: /Opinion Segment Labels/data/yvsjCA6Y5Fc
#       Dataset: /Opinion Segment Labels/data/yvsjCA6Y5Fc/features
#         shape: (23, 1)
#         dtype: float32
#         values: [[-2. ]
#  [-1.2]
#  [-2. ]
#  [-0.2]
#  [ 0.4]]...
#       Dataset: /Opinion Segment Labels/data/yvsjCA6Y5Fc/intervals
#         shape: (23, 2)
#         dtype: float32
#         values: [[1.2471655e-02 8.0043087e+00]
#  [8.0043087e+00 1.0668254e+01]
#  [2.3010204e+01 2.6582087e+01]
#  [2.6582087e+01 3.2608391e+01]
#  [3.2608391e+01 3.4334469e+01]]...
#     Group: /Opinion Segment Labels/data/zhpQhgha_KU
#       Dataset: /Opinion Segment Labels/data/zhpQhgha_KU/features
#         shape: (35, 1)
#         dtype: float32
#         values: [[-1.6]
#  [ 1.6]
#  [-1.6]
#  [-1.6]
#  [-2.2]]...
#       Dataset: /Opinion Segment Labels/data/zhpQhgha_KU/intervals
#         shape: (35, 2)
#         dtype: float32
#         values: [[ 6.8170066 11.366667 ]
#  [19.268707  22.631065 ]
#  [22.631065  30.423355 ]
#  [30.423355  31.840136 ]
#  [31.840136  35.74127  ]]...
#   Group: /Opinion Segment Labels/metadata
#     Dataset: /Opinion Segment Labels/metadata/alignment compatible
#       shape: (1,)
#       dtype: object
#       values: [b'true']...
#     Dataset: /Opinion Segment Labels/metadata/computational sequence description
#       shape: (1,)
#       dtype: object
#       values: [b'"Sentiment scores for opinions in CMU-MOSI Dataset"']...
#     Dataset: /Opinion Segment Labels/metadata/computational sequence version
#       shape: (1,)
#       dtype: object
#       values: [b'1.0']...
#     Dataset: /Opinion Segment Labels/metadata/contact
#       shape: (1,)
#       dtype: object
#       values: [b'"abagherz@andrew.cmu.edu"']...
#     Dataset: /Opinion Segment Labels/metadata/creator
#       shape: (1,)
#       dtype: object
#       values: [b'"Amir Zadeh"']...
#     Dataset: /Opinion Segment Labels/metadata/dataset bib citation
#       shape: (1,)
#       dtype: object
#       values: [b'"@article{zadeh2016multimodal,title={Multimodal sentiment intensity analysis in videos: Facial gestures and verbal messages},author={Zadeh, Amir and Zellers, Rowan and Pincus, Eli and Morency, Louis-Philippe},journal={IEEE Intelligent Systems},volume={31},number={6},pages={82--88},year={2016},publisher={IEEE}}"']...
#     Dataset: /Opinion Segment Labels/metadata/dataset name
#       shape: (1,)
#       dtype: object
#       values: [b'"CMU-MOSI"']...
#     Dataset: /Opinion Segment Labels/metadata/dataset version
#       shape: (1,)
#       dtype: object
#       values: [b'1.0']...
#     Dataset: /Opinion Segment Labels/metadata/dimension names
#       shape: (1,)
#       dtype: object
#       values: [b'["sentiment score"]']...
#     Dataset: /Opinion Segment Labels/metadata/featureset bib citation
#       shape: (1,)
#       dtype: object
#       values: [b'"@online{amt, author = {Amazon},title = {Amazon Mechanical Turk},year = {2017},url = {https://www.mturk.com}}"']...
#     Dataset: /Opinion Segment Labels/metadata/md5
#       shape: (1,)
#       dtype: object
#       values: [b'null']...
#     Dataset: /Opinion Segment Labels/metadata/root name
#       shape: (1,)
#       dtype: object
#       values: [b'"Opinion Segment Labels"']...
#     Dataset: /Opinion Segment Labels/metadata/uuid
#       shape: (1,)
#       dtype: object
#       values: [b'"964b6049-a6f0-4cb8-a647-be87e255fe38"']...

# %%
import h5py
import csv

def create_csv_from_hdf5(file_path, output_csv):
    with h5py.File(file_path, 'r') as f:
        # Prepare CSV file for writing
        with open(output_csv, 'w', newline='') as csvfile:
            csvwriter = csv.writer(csvfile)
            
            # Write the header
            header = ['id', 'interval_start', 'interval_end'] + [f'feature_{i}' for i in range(7)]
            csvwriter.writerow(header)

            # Iterate through all subgroups under /All Labels/data
            data_group = f['All Labels/data']
            for key in data_group.keys():
                subgroup = data_group[key]
                features = subgroup['features'][:]
                intervals = subgroup['intervals'][:]
                
                # Write each feature set and its corresponding interval to the CSV file
                for i in range(features.shape[0]):
                    row = [key, intervals[i][0], intervals[i][1]] + list(features[i])
                    csvwriter.writerow(row)

if __name__ == '__main__':
    file_path = 'CMU_MOSI_Labels.csd'  # Path to your HDF5 file
    output_csv = 'mosi.csv'     # Output CSV file name
    create_csv_from_hdf5(file_path, output_csv)
    print(f"CSV file '{output_csv}' created successfully!")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 29
#      27 file_path = 'CMU_MOSI_Labels.csd'  # Path to your HDF5 file
#      28 output_csv = 'mosi.csv'     # Output CSV file name
# ---> 29 create_csv_from_hdf5(file_path, output_csv)
#      30 print(f"CSV file '{output_csv}' created successfully!")
#
# Cell In[3], line 15, in create_csv_from_hdf5(file_path, output_csv)
#      12 csvwriter.writerow(header)
#      14 # Iterate through all subgroups under /All Labels/data
# ---> 15 data_group = f['All Labels/data']
#      16 for key in data_group.keys():
#      17     subgroup = data_group[key]
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File /opt/anaconda3/lib/python3.11/site-packages/h5py/_hl/group.py:357, in Group.__getitem__(self, name)
#     355         raise ValueError("Invalid HDF5 object reference")
#     356 elif isinstance(name, (bytes, str)):
# --> 357     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     358 else:
#     359     raise TypeError("Accessing a group is done with bytes or str, "
#     360                     "not {}".format(type(name)))
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5o.pyx:241, in h5py.h5o.open()
#
# KeyError: 'Unable to open object (component not found)'
